# %%
#!pip install snntorch

# %%
# !pip install matplotlib==3.10.7
# Out:
# Collecting matplotlib==3.10.7
#   Downloading matplotlib-3.10.7-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 60.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.23 in /toolkit-cache/1.1.2/python3.10/kernel-libs/lib/python3.10/site-packages (from matplotlib==3.10.7) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /toolkit-cache/1.1.2/python3.10/kernel-libs/lib/python3.10/site-packages (from matplotlib==3.10.7) (24.1)
# Requirement already satisfied: python-dateutil>=2.7 in /toolkit-cache/1.1.2/python3.10/kernel-libs/lib/python3.10/site-packages (from matplotlib==3.10.7) (2.9.0.post0)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.60.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 65.3 MB/s eta 0:00:00
# Collecting pillow>=8
#   Downloading pillow-12.0.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 85.0 MB/s eta 0:00:00
# Collecting pyparsing>=3
#   Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.9/113.9 kB 20.8 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.0/325.0 kB 26.0 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.9-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 54.7 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /toolkit-cache/1.1.2/python3.10/kernel-libs/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib==3.10.7) (1.16.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.60.1 kiwisolver-1.4.9 matplotlib-3.10.7 pillow-12.0.0 pyparsing-3.2.5
#
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def update_t(U_t,I_t1, th,B):
  U_th=th*(U_t>th)
  U_t_1 = B*U_t+I_t1-U_th
  return U_t_1

def lif_test(I,U_0,th,B):
  U=np.zeros(len(I))
  U[0] = U_0
  for t in range(len(I)-1):
    U[t+1] = update_t(U[t],I[t],th,B)
  return U

# %%
np.zeros(len(I_test))+3*(I_test>3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 np.zeros(len(I_test))+3*(I_test>3)
#
# NameError: name 'I_test' is not defined

# %%
I_test=np.zeros(100)
I_test[40]=3
I_test[50]=4
I_test[60]=2


U_test=lif_test(I_test,0,5,0.9)
plt.plot(U_test)
plt.show()

# %%
class lifer:
    def __init__(self, inputs, U0, Uth, B):
        self.I = sum(inputs)
        self.U0 = U0
        self.Uth = Uth
        self.B = B
        self.U = np.zeros(len(self.I))
        self.U[0] = U0
        self.spikes = np.zeros(len(self.I))
    def update(self):
        # ver la edo de la membrana

        for t in range(len(self.I)-1):
            U_th=self.Uth*(self.U[t]>self.Uth)
            self.U[t+1] = self.B*self.U[t]+self.I[t]-U_th

        # generar el output 1 tiempo después de superar el umbral
        up=3*(self.U>=self.Uth)
        up2 = up[:-1] 
        shifted_data_padded = np.insert(up2, 0, 0) # Alternatively: np.concatenate(([0], data_slice))
        self.spikes = self.spikes + shifted_data_padded
  
    def plot(self,val=0):
        fig, axs = plt.subplots(3)
        axs[0].plot(self.I)
        axs[0].set_title("input")
        axs[1].plot(self.U)
        axs[1].set_title("membrana")
        axs[2].plot(self.spikes)
        axs[2].set_title("output")
        fig.tight_layout()

# %%
I_test=np.zeros(100)
I_test[40]=3
I_test[41]=3
I_test[54]=3
I_test[60]=4
I_test[65]=4

prueba=lifer([I_test],0,5,0.9)

# %%
prueba.update()
out=lifer([prueba.spikes],0,3.8,0.9)
out.update()
out2=lifer([out.spikes,I_test],0,3.8,0.5)
out2.update()

# %%
prueba.plot()

# %%
out.plot()

# %%
out2.plot()

# %%
sum([np.array((0,1)),np.array((2,0))])
# Out:
# array([2, 1])

# %%
I_test = np.zeros(100)
I_test[30] = 1
I_test[40] = 3
I_test[50] = 3
I_test[54] = 3
I_test[60] = 4
I_test[65] = 4
I_test[70] = 4
I_test[75] = 4
I_test[80] = 4
I_test[85] = 4
I_test[90] = 4

neuronas = unir_neuronas(I_test, n=4, Uth=[4, 4, 4, 4], B=[0.9, 0.9, 0.9, 0.9])

#grafico
for i, neu in enumerate(neuronas):
    print(f"Neurona {i+1}")
    neu.plot()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 I_test = np.zeros(100)
#       2 I_test[30] = 1
#       3 I_test[40] = 3
#
# NameError: name 'np' is not defined

# %%
import pandas as pd

test = pd.read_csv("series/data_basic_all3.csv")

# %% [markdown]
# ##

# %%
test["0"].unique()
# Out:
# array([10., 20., 42., 31., 30., 32., 33., 11., 24., 21., 40.,  0.])

# %%
test[test["0"]==0]
# Out:
#          0     label
# 25643  0.0  0.993721
# 25644  0.0  0.995290
# 25645  0.0  0.996860
# 25646  0.0  0.998430
# 25647  0.0  1.000000
